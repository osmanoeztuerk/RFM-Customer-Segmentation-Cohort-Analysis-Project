# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply RFM Analysis and Customer Segmentation using K-Means Clustering. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quan
#     tity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data
#
#      from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dt


import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10,6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %%
df0 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Capstone 1/Online Retail.xlsx")

# %%
df = df0.copy()

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0 536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1 536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2 536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3 536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4 536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  float64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#         Quantity  UnitPrice  CustomerID
# count 541909.000 541909.000  406829.000
# mean       9.552      4.611   15287.691
# std      218.081     96.760    1713.600
# min   -80995.000 -11062.060   12346.000
# 25%        1.000      1.250   13953.000
# 50%        3.000      2.080   15152.000
# 75%       10.000      4.130   16791.000
# max    80995.000  38970.000   18287.000

# %%
#df.describe(include='O') # Categorical values statistics

# %%
df.describe(include="all")
# Out:
#         InvoiceNo StockCode                         Description   Quantity  \
# count  541909.000    541909                              540455 541909.000
# unique  25900.000      4070                                4223        NaN
# top    573585.000    85123A  WHITE HANGING HEART T-LIGHT HOLDER        NaN
# freq     1114.000      2313                                2369        NaN
# first         NaN       NaN                                 NaN        NaN
# last          NaN       NaN                                 NaN        NaN
# mean          NaN       NaN                                 NaN      9.552
# std           NaN       NaN                                 NaN    218.081
# min           NaN       NaN                                 NaN -80995.000
# 25%           NaN       NaN                                 NaN      1.000
# 50%           NaN       NaN                                 NaN      3.000
# ...

# %%
df.isna().sum()   # If we have any NaN value in the df, we have some nulls in Descriptoion and CustomerID
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.duplicated().value_counts()  # if there is any duplicate
# Out:
# False    536641
# True       5268
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#         InvoiceNo StockCode                        Description  Quantity  \
# 517    536409.000 21866.000        UNION JACK FLAG LUGGAGE TAG     1.000
# 527    536409.000 22866.000      HAND WARMER SCOTTY DOG DESIGN     1.000
# 537    536409.000 22900.000    SET 2 TEA TOWELS I LOVE LONDON      1.000
# 539    536409.000 22111.000       SCOTTIE DOG HOT WATER BOTTLE     1.000
# 555    536412.000 22327.000  ROUND SNACK BOXES SET OF 4 SKULLS     1.000
# ...           ...       ...                                ...       ...
# 541675 581538.000 22068.000        BLACK PIRATE TREASURE CHEST     1.000
# 541689 581538.000 23318.000     BOX OF 6 MINI VINTAGE CRACKERS     1.000
# 541692 581538.000 22992.000             REVOLVER WOODEN RULER      1.000
# 541699 581538.000 22694.000                       WICKER STAR      1.000
# 541701 581538.000 23343.000       JUMBO BAG VINTAGE CHRISTMAS      1.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
df['Description'].unique()
# Out:
# array(['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN',
#        'CREAM CUPID HEARTS COAT HANGER', ..., 'lost',
#        'CREAM HANGING HEART T-LIGHT HOLDER',
#        'PAPER CRAFT , LITTLE BIRDIE'], dtype=object)

# %%
df = df.drop_duplicates(subset=None, keep='first')   #drop the duplicated values

# %%
df.duplicated().value_counts()   # All the duplicates have gone :)
# Out:
# False    536641
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 536641 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    536641 non-null  object
#  1   StockCode    536641 non-null  object
#  2   Description  535187 non-null  object
#  3   Quantity     536641 non-null  float64
#  4   InvoiceDate  536641 non-null  datetime64[ns]
#  5   UnitPrice    536641 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      536641 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 36.8+ MB

# %%
df.isnull().sum()   # we still have lots of NaN
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.describe()  # We have some minus values for Quantitiy and unit price
# Out:
#         Quantity  UnitPrice  CustomerID
# count 536641.000 536641.000  401604.000
# mean       9.620      4.633   15281.161
# std      219.130     97.233    1714.006
# min   -80995.000 -11062.060   12346.000
# 25%        1.000      1.250   13939.000
# 50%        3.000      2.080   15145.000
# 75%       10.000      4.130   16784.000
# max    80995.000  38970.000   18287.000

# %%
def summary(df, pred=None):
  
    Types = df.dtypes
    Counts = df.apply(lambda x: x.count())
    Min = df.min()
    Max = df.max()
    Uniques = df.apply(lambda x: x.unique().shape[0])
    Nulls = df.apply(lambda x: x.isnull().sum())
    print('Data shape:', df.shape)

    if pred is None:
        cols = ['Types', 'Counts', 'Uniques', 'Nulls', 'Min', 'Max']
        str = pd.concat([Types, Counts, Uniques, Nulls, Min, Max], axis = 1, sort=True)

    str.columns = cols
    print('___________________________\nData Types:')
    print(str.Types.value_counts())
    print('___________________________')
    return str

display(summary(df).sort_values(by='Nulls', ascending=False))
# Out:
# Data shape: (536641, 8)
# ___________________________
# Data Types:
# object            4
# float64           3
# datetime64[ns]    1
# Name: Types, dtype: int64
# ___________________________
#                       Types  Counts  Uniques   Nulls                  Min  \
# CustomerID          float64  401604     4373  135037            12346.000
# Description          object  535187     4224    1454                  NaN
# Country              object  536641       38       0            Australia
# InvoiceDate  datetime64[ns]  536641    23260       0  2010-12-01 08:26:00
# InvoiceNo            object  536641    25900       0                  NaN
# Quantity            float64  536641      722       0           -80995.000
# StockCode            object  536641     4070       0                  NaN
# UnitPrice           float64  536641     1630       0           -11062.060
#
#                              Max
# CustomerID             18287.000
# Description                  NaN
# ...

# %% [markdown]
# There are some negative values for UnitPrice and Quantity. They are most likely returned items. Maybe we should delete them too

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df[["InvoiceNo", "Quantity", "UnitPrice"]].describe(include="all")
# Out:
#         InvoiceNo   Quantity  UnitPrice
# count  536641.000 536641.000 536641.000
# unique  25900.000        NaN        NaN
# top    573585.000        NaN        NaN
# freq     1114.000        NaN        NaN
# mean          NaN      9.620      4.633
# std           NaN    219.130     97.233
# min           NaN -80995.000 -11062.060
# 25%           NaN      1.000      1.250
# 50%           NaN      3.000      2.080
# 75%           NaN     10.000      4.130
# max           NaN  80995.000  38970.000

# %%
df[df['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount    -1.000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 235      C536391 22556.000    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391 21984.000  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391 21983.000  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...          ...       ...                               ...       ...
# 535188   C581490 23144.000   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 536280   C581499         M                            Manual    -1.000
# 536447   C581568 21258.000        VICTORIAN SEWING BOX LARGE    -5.000
# 536448   C581569 84978.000  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 536449   C581569 20979.000     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df['Quantity'] > 0]
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0      536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1      536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2      536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3      536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4      536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...           ...       ...                                  ...       ...
# 536636 581587.000 22613.000          PACK OF 20 SPACEBOY NAPKINS    12.000
# 536637 581587.000 22899.000         CHILDREN'S APRON DOLLY GIRL      6.000
# 536638 581587.000 23254.000        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 536639 581587.000 23255.000      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 536640 581587.000 22138.000        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df['UnitPrice'] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 297646   A563186         B  Adjust bad debt     1.000 2011-08-12 14:51:00
# 297647   A563187         B  Adjust bad debt     1.000 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 297646 -11062.060         NaN  United Kingdom
# 297647 -11062.060         NaN  United Kingdom

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# hint: If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %%
df['cancellation']=df.InvoiceNo.str.extract('([C])').fillna(0).replace({'C':1})
df['cancellation'].value_counts()
# Out:
# 0    527390
# 1      9251
# Name: cancellation, dtype: int64

# %%
df.sample(5)
# Out:
#         InvoiceNo StockCode                   Description  Quantity  \
# 340163 566913.000 23311.000   VINTAGE CHRISTMAS STOCKING      6.000
# 185740 552963.000 22084.000        PAPER CHAIN KIT EMPIRE     1.000
# 332053 566262.000 22575.000  METAL MERRY CHRISTMAS WREATH     1.000
# 388663 570680.000 23310.000       BUBBLEGUM RING ASSORTED    36.000
# 196901 554054.000 23112.000      PARISIENNE CURIO CABINET     1.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 340163 2011-09-15 14:07:00      2.550   17602.000  United Kingdom
# 185740 2011-05-12 12:57:00      2.950   16743.000  United Kingdom
# 332053 2011-09-11 12:56:00      1.950   15527.000  United Kingdom
# 388663 2011-10-11 15:36:00      0.420   13969.000  United Kingdom
# 196901 2011-05-20 15:29:00     14.960         NaN  United Kingdom
#
#         cancellation
# 340163             0
# 185740             0
# 332053             0
# 388663             0
# 196901             0

# %%
df.dtypes
# Out:
# InvoiceNo               object
# StockCode               object
# Description             object
# Quantity               float64
# InvoiceDate     datetime64[ns]
# UnitPrice              float64
# CustomerID             float64
# Country                 object
# cancellation             int64
# dtype: object

# %%
df['cancellation'] = df['cancellation'].astype(float)  # All datatypes are object or float

# %%
df['cancellation'].value_counts()
# Out:
# 0.000    527390
# 1.000      9251
# Name: cancellation, dtype: int64

# %%
df[(df['cancellation'] == 1) & (df['Quantity'] > 0)]   # Bu sekilden cancellation olanlarin quantitilerinin pozitif olmadigini görüyoruz :)
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, cancellation]
# Index: []

# %%
df[df['Quantity'] < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount    -1.000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 235      C536391 22556.000    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391 21984.000  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391 21983.000  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...          ...       ...                               ...       ...
# 535188   C581490 23144.000   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 536280   C581499         M                            Manual    -1.000
# 536447   C581568 21258.000        VICTORIAN SEWING BOX LARGE    -5.000
# 536448   C581569 84978.000  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 536449   C581569 20979.000     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df[df['UnitPrice'] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 297646   A563186         B  Adjust bad debt     1.000 2011-08-12 14:51:00
# 297647   A563187         B  Adjust bad debt     1.000 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  cancellation
# 297646 -11062.060         NaN  United Kingdom         0.000
# 297647 -11062.060         NaN  United Kingdom         0.000

# %%
len(df[df['UnitPrice'] < 0])
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# InvoiceNo            0
# StockCode            0
# Description       1454
# Quantity             0
# InvoiceDate          0
# UnitPrice            0
# CustomerID      135037
# Country              0
# cancellation         0
# dtype: int64

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %%
len(df[df['Quantity'] < 0])
# Out:
# 10587

# %% [markdown]
# #### Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
df[df["InvoiceNo"].str.startswith('C', na=False)]["InvoiceNo"].count()
# Out:
# 9251

# %%
df[df["InvoiceNo"].str.startswith('C', na=False)]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount    -1.000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 235      C536391 22556.000    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391 21984.000  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391 21983.000  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...          ...       ...                               ...       ...
# 535188   C581490 23144.000   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 536280   C581499         M                            Manual    -1.000
# 536447   C581568 21258.000        VICTORIAN SEWING BOX LARGE    -5.000
# 536448   C581569 84978.000  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 536449   C581569 20979.000     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
(df[df["InvoiceNo"].str.startswith('C', na=False)].count()) / df.count()*100   # Cancel laarin orani %2 ye yakin
# Out:
# InvoiceNo      1.724
# StockCode      1.724
# Description    1.729
# Quantity       1.724
# InvoiceDate    1.724
# UnitPrice      1.724
# CustomerID     2.209
# Country        1.724
# cancellation   1.724
# dtype: float64

# %%
pd.DataFrame(np.vstack(((df[df['Quantity'] < 0]), df[df["InvoiceNo"].str.startswith('C', na=False)])))
# Out:
#              0         1                                 2       3  \
# 0      C536379         D                          Discount  -1.000
# 1      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS  -1.000
# 2      C536391 22556.000    PLASTERS IN TIN CIRCUS PARADE  -12.000
# 3      C536391 21984.000  PACK OF 12 PINK PAISLEY TISSUES  -24.000
# 4      C536391 21983.000  PACK OF 12 BLUE PAISLEY TISSUES  -24.000
# ...        ...       ...                               ...     ...
# 19833  C581490 23144.000   ZINC T-LIGHT HOLDER STARS SMALL -11.000
# 19834  C581499         M                            Manual  -1.000
# 19835  C581568 21258.000        VICTORIAN SEWING BOX LARGE  -5.000
# 19836  C581569 84978.000  HANGING HEART JAR T-LIGHT HOLDER  -1.000
# 19837  C581569 20979.000     36 PENCILS TUBE RED RETROSPOT  -5.000
#
#                         4       5         6               7     8
# 0     2010-12-01 09:41:00  27.500 14527.000  United Kingdom 1.000
# ...

# %%
pd.concat([(df[df['Quantity'] < 0]), df[df["InvoiceNo"].str.startswith('C', na=False)]], ignore_index=True).drop_duplicates()  
# duplicate leri düsürünce toplam cancel leri buluyoruz bir daha
# burada Quantity negatif ve Cancel olanlar toplamda 10587 rows × 9 columns dir.
# Out:
#       InvoiceNo StockCode                       Description  Quantity  \
# 0       C536379         D                          Discount    -1.000
# 1       C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 2       C536391 22556.000    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 3       C536391 21984.000  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 4       C536391 21983.000  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...         ...       ...                               ...       ...
# 10582   C581490 23144.000   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 10583   C581499         M                            Manual    -1.000
# 10584   C581568 21258.000        VICTORIAN SEWING BOX LARGE    -5.000
# 10585   C581569 84978.000  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 10586   C581569 20979.000     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#               InvoiceDate  UnitPrice  CustomerID         Country  cancellation
# ...

# %%
len(df[df['UnitPrice'] < 0])    #  hesaplari denklestirmek icin olabilir.
# Out:
# 2

# %%
df[df['UnitPrice'] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 297646   A563186         B  Adjust bad debt     1.000 2011-08-12 14:51:00
# 297647   A563187         B  Adjust bad debt     1.000 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  cancellation
# 297646 -11062.060         NaN  United Kingdom         0.000
# 297647 -11062.060         NaN  United Kingdom         0.000

# %% [markdown]
# ### iii. Handling Missing Values

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %% [markdown]
# **RFM (Recency, Frequency, Monetary)** Cohort Analysis is a method of customer segmentation that divides customers into groups based on their past purchases and behaviors. RFM stands for:
#
# Recency: the number of days since the customer's last purchase
# Frequency: the number of purchases made by the customer
# Monetary: the amount of money spent by the customer
# Cohort analysis involves dividing customers into groups based on when they made their first purchase, and then analyzing the purchasing behaviors of each cohort over time. The goal of RFM Cohort Analysis is to identify patterns in customer behavior that can inform business decisions and improve customer retention and loyalty.

# %%
df.CustomerID.unique()
# Out:
# array([17850., 13047., 12583., ..., 13298., 14569., 12713.])

# %%
len(df.CustomerID.unique())  # number of customer
# Out:
# 4373

# %%
df.Quantity[df.Quantity < 0].count()  # number of returns
# Out:
# 10587

# %%
df.Quantity[df.Quantity > 0].count()   # number of sales
# Out:
# 526054

# %%
df.Quantity[df.Quantity == 0].count()    # Bunu niye yapiyorum bende bilmiyorum :)
# Out:
# 0

# %%
print('The first order date in the data is: ')
print(df['InvoiceDate'].min())

print('The last order date in the data is: ')
print(df['InvoiceDate'].max())
# Out:
# The first order date in the data is:
# 2010-12-01 08:26:00
# The last order date in the data is:
# 2011-12-09 12:50:00

# %%
def summary(df, pred=None):
  
    Types = df.dtypes
    Counts = df.apply(lambda x: x.count())
    Min = df.min()
    Max = df.max()
    Uniques = df.apply(lambda x: x.unique().shape[0])
    Nulls = df.apply(lambda x: x.isnull().sum())
    print('Data shape:', df.shape)

    if pred is None:
        cols = ['Types', 'Counts', 'Uniques', 'Nulls', 'Min', 'Max']
        str = pd.concat([Types, Counts, Uniques, Nulls, Min, Max], axis = 1, sort=True)

    str.columns = cols
    print('___________________________\nData Types:')
    print(str.Types.value_counts())
    print('___________________________')
    return str

display(summary(df).sort_values(by='Nulls', ascending=False))
# Out:
# Data shape: (536641, 9)
# ___________________________
# Data Types:
# object            4
# float64           4
# datetime64[ns]    1
# Name: Types, dtype: int64
# ___________________________
#                        Types  Counts  Uniques   Nulls                  Min  \
# CustomerID           float64  401604     4373  135037            12346.000
# Description           object  535187     4224    1454                  NaN
# Country               object  536641       38       0            Australia
# InvoiceDate   datetime64[ns]  536641    23260       0  2010-12-01 08:26:00
# InvoiceNo             object  536641    25900       0                  NaN
# Quantity             float64  536641      722       0           -80995.000
# StockCode             object  536641     4070       0                  NaN
# UnitPrice            float64  536641     1630       0           -11062.060
# cancellation         float64  536641        2       0                0.000
#
# ...

# %%
df[df["Quantity"] <= 0 ]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount    -1.000
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS    -1.000
# 235      C536391 22556.000    PLASTERS IN TIN CIRCUS PARADE    -12.000
# 236      C536391 21984.000  PACK OF 12 PINK PAISLEY TISSUES    -24.000
# 237      C536391 21983.000  PACK OF 12 BLUE PAISLEY TISSUES    -24.000
# ...          ...       ...                               ...       ...
# 535188   C581490 23144.000   ZINC T-LIGHT HOLDER STARS SMALL   -11.000
# 536280   C581499         M                            Manual    -1.000
# 536447   C581568 21258.000        VICTORIAN SEWING BOX LARGE    -5.000
# 536448   C581569 84978.000  HANGING HEART JAR T-LIGHT HOLDER    -1.000
# 536449   C581569 20979.000     36 PENCILS TUBE RED RETROSPOT    -5.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df[df["UnitPrice"] <= 0 ]
# Out:
#         InvoiceNo StockCode                   Description  Quantity  \
# 605    536414.000 22139.000                           NaN    56.000
# 1934   536545.000 21134.000                           NaN     1.000
# 1935   536546.000 22145.000                           NaN     1.000
# 1936   536547.000 37509.000                           NaN     1.000
# 1951   536549.000    85226A                           NaN     1.000
# ...           ...       ...                           ...       ...
# 531753 581234.000 72817.000                           NaN    27.000
# 533259 581406.000    46000M  POLYESTER FILLER PAD 45x45cm   240.000
# 533260 581406.000    46000S  POLYESTER FILLER PAD 40x40cm   300.000
# 533309 581408.000 85175.000                           NaN    20.000
# 533665 581422.000 23169.000                       smashed  -235.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 605    2010-12-01 11:52:00      0.000         NaN  United Kingdom
# ...

# %%
df.shape
# Out:
# (536641, 9)

# %%
df= df.drop_duplicates()
df
# toplamda 11763 cancellation gibi birsey var
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0      536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1      536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2      536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3      536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4      536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...           ...       ...                                  ...       ...
# 536636 581587.000 22613.000          PACK OF 20 SPACEBOY NAPKINS    12.000
# 536637 581587.000 22899.000         CHILDREN'S APRON DOLLY GIRL      6.000
# 536638 581587.000 23254.000        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 536639 581587.000 23255.000      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 536640 581587.000 22138.000        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
def summary(df, pred=None):
  
    Types = df.dtypes
    Counts = df.apply(lambda x: x.count())
    Min = df.min()
    Max = df.max()
    Uniques = df.apply(lambda x: x.unique().shape[0])
    Nulls = df.apply(lambda x: x.isnull().sum())
    print('Data shape:', df.shape)

    if pred is None:
        cols = ['Types', 'Counts', 'Uniques', 'Nulls', 'Min', 'Max']
        str = pd.concat([Types, Counts, Uniques, Nulls, Min, Max], axis = 1, sort=True)

    str.columns = cols
    print('___________________________\nData Types:')
    print(str.Types.value_counts())
    print('___________________________')
    return str

display(summary(df).sort_values(by='Nulls', ascending=False))
# Out:
# Data shape: (536641, 9)
# ___________________________
# Data Types:
# object            4
# float64           4
# datetime64[ns]    1
# Name: Types, dtype: int64
# ___________________________
#                        Types  Counts  Uniques   Nulls                  Min  \
# CustomerID           float64  401604     4373  135037            12346.000
# Description           object  535187     4224    1454                  NaN
# Country               object  536641       38       0            Australia
# InvoiceDate   datetime64[ns]  536641    23260       0  2010-12-01 08:26:00
# InvoiceNo             object  536641    25900       0                  NaN
# Quantity             float64  536641      722       0           -80995.000
# StockCode             object  536641     4070       0                  NaN
# UnitPrice            float64  536641     1630       0           -11062.060
# cancellation         float64  536641        2       0                0.000
#
# ...

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0      536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1      536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2      536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3      536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4      536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...           ...       ...                                  ...       ...
# 536636 581587.000 22613.000          PACK OF 20 SPACEBOY NAPKINS    12.000
# 536637 581587.000 22899.000         CHILDREN'S APRON DOLLY GIRL      6.000
# 536638 581587.000 23254.000        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 536639 581587.000 23255.000      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 536640 581587.000 22138.000        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df.shape
# Out:
# (536641, 9)

# %%
df = df.drop(df[df['Quantity'] < 0].index)
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0      536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1      536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2      536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3      536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4      536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...           ...       ...                                  ...       ...
# 536636 581587.000 22613.000          PACK OF 20 SPACEBOY NAPKINS    12.000
# 536637 581587.000 22899.000         CHILDREN'S APRON DOLLY GIRL      6.000
# 536638 581587.000 23254.000        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 536639 581587.000 23255.000      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 536640 581587.000 22138.000        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df = df.drop(df[df['UnitPrice'] < 0].index)
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0      536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1      536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2      536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3      536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4      536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...           ...       ...                                  ...       ...
# 536636 581587.000 22613.000          PACK OF 20 SPACEBOY NAPKINS    12.000
# 536637 581587.000 22899.000         CHILDREN'S APRON DOLLY GIRL      6.000
# 536638 581587.000 23254.000        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 536639 581587.000 23255.000      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 536640 581587.000 22138.000        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
df.Description.isnull().sum()  # Elimizde toplamda olmayan data sayisi
# Out:
# 592

# %%
def summary(df, pred=None):
  
    Types = df.dtypes
    Counts = df.apply(lambda x: x.count())
    Min = df.min()
    Max = df.max()
    Uniques = df.apply(lambda x: x.unique().shape[0])
    Nulls = df.apply(lambda x: x.isnull().sum())
    print('Data shape:', df.shape)

    if pred is None:
        cols = ['Types', 'Counts', 'Uniques', 'Nulls', 'Min', 'Max']
        str = pd.concat([Types, Counts, Uniques, Nulls, Min, Max], axis = 1, sort=True)

    str.columns = cols
    print('___________________________\nData Types:')
    print(str.Types.value_counts())
    print('___________________________')
    return str

display(summary(df).sort_values(by='Nulls', ascending=False))
# Out:
# Data shape: (526052, 9)
# ___________________________
# Data Types:
# object            4
# float64           4
# datetime64[ns]    1
# Name: Types, dtype: int64
# ___________________________
#                        Types  Counts  Uniques   Nulls                  Min  \
# CustomerID           float64  392732     4340  133320            12346.000
# Description           object  525460     4078     592                  NaN
# Country               object  526052       38       0            Australia
# InvoiceDate   datetime64[ns]  526052    19050       0  2010-12-01 08:26:00
# InvoiceNo             object  526052    20726       0                  NaN
# Quantity             float64  526052      393       0                1.000
# StockCode             object  526052     3941       0                  NaN
# UnitPrice            float64  526052     1292       0                0.000
# cancellation         float64  526052        1       0                0.000
#
# ...

# %%
df.dropna(subset=["Description"], inplace=True)

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0      536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1      536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2      536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3      536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4      536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...           ...       ...                                  ...       ...
# 536636 581587.000 22613.000          PACK OF 20 SPACEBOY NAPKINS    12.000
# 536637 581587.000 22899.000         CHILDREN'S APRON DOLLY GIRL      6.000
# 536638 581587.000 23254.000        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 536639 581587.000 23255.000      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 536640 581587.000 22138.000        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df.CustomerID.isnull().sum() # Elimizde toplamda olmayan data sayisi
# Out:
# 132728

# %%
df[(df["UnitPrice"] > 0) & (df["Quantity"] > 0)]
df.shape
# Out:
# (525460, 9)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df.groupby("CustomerID").InvoiceNo.nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 12748.000    210
# 14911.000    201
# 17841.000    124
# 13089.000     97
# 14606.000     93
#             ...
# 14355.000      1
# 13403.000      1
# 15488.000      1
# 14353.000      1
# 12346.000      1
# Name: InvoiceNo, Length: 4339, dtype: int64

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
df.groupby(["StockCode", "CustomerID"]).Quantity.mean()
# Out:
# StockCode  CustomerID
# 10002.0    12451.000    12.000
#            12510.000    24.000
#            12583.000    48.000
#            12637.000    12.000
#            12673.000     1.000
#                          ...
# POST       17404.000     1.500
#            17444.000     1.000
#            17788.000     1.000
#            17828.000     4.000
#            17935.000     1.000
# Name: Quantity, Length: 266802, dtype: float64

# %%
df.groupby(["StockCode", "CustomerID"]).Quantity.nunique().mean()
# Out:
# 1.1940502694882347

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df.groupby("CustomerID").StockCode.nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 14911.000    1787
# 12748.000    1768
# 17841.000    1323
# 14096.000    1119
# 14298.000     884
#              ...
# 13366.000       1
# 13391.000       1
# 13452.000       1
# 16078.000       1
# 12346.000       1
# Name: StockCode, Length: 4339, dtype: int64

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df["Revenue"] = df["Quantity"] * df["UnitPrice"]

# %%
df
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 0      536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1      536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2      536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3      536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4      536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
# ...           ...       ...                                  ...       ...
# 525455 581587.000 22613.000          PACK OF 20 SPACEBOY NAPKINS    12.000
# 525456 581587.000 22899.000         CHILDREN'S APRON DOLLY GIRL      6.000
# 525457 581587.000 23254.000        CHILDRENS CUTLERY DOLLY GIRL      4.000
# 525458 581587.000 23255.000      CHILDRENS CUTLERY CIRCUS PARADE     4.000
# 525459 581587.000 22138.000        BAKING SET 9 PIECE RETROSPOT      3.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# ...

# %%
df.groupby("Country").Revenue.sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom         9001744.094
# Netherlands             285446.340
# EIRE                    283140.520
# Germany                 228678.400
# France                  209625.370
# Australia               138453.810
# Spain                    61558.560
# Switzerland              57067.600
# Belgium                  41196.340
# Sweden                   38367.830
# Japan                    37416.370
# Norway                   36165.440
# Portugal                 33683.050
# Finland                  22546.080
# Singapore                21279.290
# Channel Islands          20440.540
# Denmark                  18955.340
# Italy                    17483.240
# Hong Kong                15483.000
# Cyprus                   13502.850
# Austria                  10198.680
# Israel                    8129.410
# Poland                    7334.650
# Greece                    4760.520
# Unspecified               4740.940
# Iceland                   4310.000
# ...

# %% [markdown]
# 2. Visualize number of customer per country

# %%
df.groupby("Country").CustomerID.nunique().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          3921
# Germany                   94
# France                    87
# Spain                     30
# Belgium                   25
# Switzerland               21
# Portugal                  19
# Italy                     14
# Finland                   12
# Austria                   11
# Norway                    10
# Netherlands                9
# Australia                  9
# Channel Islands            9
# Denmark                    9
# Cyprus                     8
# Sweden                     8
# Japan                      8
# Poland                     6
# USA                        4
# Canada                     4
# Unspecified                4
# Greece                     4
# EIRE                       3
# Israel                     3
# Malta                      2
# United Arab Emirates       2
# Bahrain                    2
# Lithuania                  1
# Czech Republic             1
# Lebanon                    1
# ...

# %%
df.groupby("Country").CustomerID.nunique().sort_values(ascending=False).plot(kind="bar");

# %% [markdown]
# 3. Visualize total cost per country

# %%
df.groupby("Country").Revenue.sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom         9001744.094
# Netherlands             285446.340
# EIRE                    283140.520
# Germany                 228678.400
# France                  209625.370
# Australia               138453.810
# Spain                    61558.560
# Switzerland              57067.600
# Belgium                  41196.340
# Sweden                   38367.830
# Japan                    37416.370
# Norway                   36165.440
# Portugal                 33683.050
# Finland                  22546.080
# Singapore                21279.290
# Channel Islands          20440.540
# Denmark                  18955.340
# Italy                    17483.240
# Hong Kong                15483.000
# Cyprus                   13502.850
# Austria                  10198.680
# Israel                    8129.410
# Poland                    7334.650
# Greece                    4760.520
# Unspecified               4740.940
# Iceland                   4310.000
# ...

# %%
df.groupby("Country").Revenue.sum().sort_values(ascending=True).plot( kind="barh")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk = df[df["Country"] == "United Kingdom"]
df_uk.head(1)
# Out:
#    InvoiceNo StockCode                         Description  Quantity  \
# 0 536365.000    85123A  WHITE HANGING HEART T-LIGHT HOLDER     6.000
#
#           InvoiceDate  UnitPrice  CustomerID         Country  cancellation  \
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom         0.000
#
#    Revenue
# 0   15.300

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
most_popular_products_Describtion = df_uk.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)
most_popular_products_Describtion
# Out:
# Description
# PAPER CRAFT , LITTLE BIRDIE          80995.000
# MEDIUM CERAMIC TOP STORAGE JAR       77036.000
# WORLD WAR 2 GLIDERS ASSTD DESIGNS    49430.000
# JUMBO BAG RED RETROSPOT              44165.000
# WHITE HANGING HEART T-LIGHT HOLDER   35726.000
# POPCORN HOLDER                       34726.000
# ASSORTED COLOUR BIRD ORNAMENT        33636.000
# PACK OF 12 LONDON TISSUES            25315.000
# PACK OF 72 RETROSPOT CAKE CASES      24963.000
# VICTORIAN GLASS HANGING T-LIGHT      23663.000
# Name: Quantity, dtype: float64

# %%
most_popular_products_StockCode = df_uk.groupby('StockCode')['Quantity'].sum().sort_values(ascending=False).head(10)
most_popular_products_StockCode
# Out:
# StockCode
# 23843.0   80995.000
# 23166.0   77036.000
# 22197.0   53320.000
# 84077.0   49430.000
# 85099B    44165.000
# 85123A    39495.000
# 84879.0   33636.000
# 22616.0   25315.000
# 21212.0   24963.000
# 22178.0   23663.000
# Name: Quantity, dtype: float64

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0 536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1 536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2 536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3 536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4 536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  UnitPrice  CustomerID         Country  cancellation  \
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom         0.000
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom         0.000
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
#
#    Revenue
# 0   15.300
# 1   20.340
# 2   22.000
# 3   20.340
# 4   20.340

# %%
df_uk.shape
# Out:
# (480549, 10)

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
df_uk["InvoiceDate"].max()
# Out:
# Timestamp('2011-12-09 12:49:00')

# %%
df_uk["InvoiceDate"].min()
# Out:
# Timestamp('2010-12-01 08:26:00')

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df_uk["Date"] = pd.to_datetime(df_uk["InvoiceDate"]).dt.date

# %%
df_uk.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0 536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1 536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2 536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3 536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4 536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  UnitPrice  CustomerID         Country  cancellation  \
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom         0.000
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom         0.000
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
#
#    Revenue        Date
# 0   15.300  2010-12-01
# 1   20.340  2010-12-01
# ...

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
df_uk["last_date_of_purchase"] = df_uk.groupby("CustomerID")["Date"].transform(max)
df_uk.sample(10)
# Out:
#         InvoiceNo StockCode                         Description  Quantity  \
# 425698 574351.000 21724.000     PANDA AND BUNNIES STICKER SHEET     1.000
# 398526 572192.000 72818.000          CHRISTMAS DECOUPAGE CANDLE     1.000
# 116495 546648.000 22076.000                  6 RIBBONS EMPIRE       1.000
# 395255 571909.000 21642.000           ASSORTED TUTTI FRUTTI PEN     3.000
# 211930 556062.000 22427.000             ENAMEL FLOWER JUG CREAM    24.000
# 35325  539451.000 21110.000         LARGE CAKE TOWEL PINK SPOTS     2.000
# 376728 570442.000 23168.000        CLASSIC CAFE SUGAR DISPENSER     1.000
# 310483 564962.000 22219.000  LOVEBIRD HANGING DECORATION WHITE      1.000
# 142522 549099.000 48138.000                  DOORMAT UNION FLAG     1.000
# 397169 572066.000 82483.000  WOOD 2 DRAWER CABINET WHITE FINISH    16.000
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 425698 2011-11-04 10:37:00      0.850   17348.000  United Kingdom
# ...

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
# !pip install timedelta
import timedelta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for timedelta: filename=timedelta-2020.12.3-py3-none-any.whl size=1603 sha256=ae2cce4f8f0022b1f411567266c28023815653f8c409ef8e275900c35684eab6
#   Stored in directory: /root/.cache/pip/wheels/37/e0/1b/4080834981be3775e6452515f78a6d8f26d071023ad2d6dacf
# Successfully built timedelta
# ...

# %%
reference_date = pd.to_datetime(dt.date(2011,12,10))

# %%
reference_date
# Out:
# Timestamp('2011-12-10 00:00:00')

# %%
df_uk['last_date_of_purchase']=pd.to_datetime(df_uk['last_date_of_purchase'])

# %%
import math
import numpy as np

# %%
df_uk["recency"] = (reference_date - df_uk["last_date_of_purchase"]).dt.days.apply(lambda x:str(x)).apply(lambda x : int(x.split('.')[0]) if x.split('.')[0] !='nan' else np.nan )

# %%
df_uk.sample(20)
# Out:
#         InvoiceNo StockCode                        Description  Quantity  \
# 217740 556541.000 20685.000              DOORMAT RED RETROSPOT     2.000
# 71300  542350.000 20985.000                   HEART CALCULATOR    12.000
# 372038 570036.000 22621.000         TRADITIONAL KNITTING NANCY    12.000
# 36146  539458.000 35961.000   FOLKART ZINC HEART CHRISTMAS DEC     1.000
# 383792 571046.000 22630.000               DOLLY GIRL LUNCH BOX     1.000
# 358050 569005.000 23076.000         ICE CREAM SUNDAE LIP GLOSS    24.000
# 481343 578344.000 84946.000       ANTIQUE SILVER T-LIGHT GLASS     8.000
# 411178 573245.000 16225.000                  RATTLE SNAKE EGGS     1.000
# 343182 567821.000 23431.000    NATURAL HANGING QUILTED HEARTS     12.000
# 407735 572897.000 22677.000      FRENCH BLUE METAL DOOR SIGN 2     1.000
# 82604  543467.000 21361.000           LOVE LARGE WOOD LETTERS      1.000
# 336272 567189.000 23319.000        BOX OF 6 MINI 50'S CRACKERS    12.000
# ...

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
df_uk = df_uk.drop(["last_date_of_purchase"],axis=1)

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480549 entries, 0 to 525444
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     480549 non-null  object
#  1   StockCode     480549 non-null  object
#  2   Description   480549 non-null  object
#  3   Quantity      480549 non-null  float64
#  4   InvoiceDate   480549 non-null  datetime64[ns]
#  5   UnitPrice     480549 non-null  float64
#  6   CustomerID    349227 non-null  float64
#  7   Country       480549 non-null  object
#  8   cancellation  480549 non-null  float64
#  9   Revenue       480549 non-null  float64
#  10  Date          480549 non-null  object
#  11  recency       349227 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(5)
# memory usage: 47.7+ MB

# %% [markdown]
# 6. Plot RFM distributions

# %%
plt.figure(figsize=(8,12))
sns.histplot(x = "recency", data = df_uk, bins = 30);

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df_uk1 = df_uk.copy()

# %%
df_uk.duplicated().sum()
# Out:
# 0

# %%
df_uk = df_uk.drop_duplicates()

# %%
df_uk.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
df_uk["frequency"] = df_uk.groupby(["CustomerID"])["InvoiceNo"].transform(lambda x: x.nunique())
df_uk.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0 536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1 536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2 536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3 536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4 536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  UnitPrice  CustomerID         Country  cancellation  \
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom         0.000
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom         0.000
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
#
#    Revenue        Date  recency  frequency
# 0   15.300  2010-12-01  373.000     34.000
# ...

# %% [markdown]
# 3. Plot RFM distributions

# %%
plt.figure(figsize=(16,9))
sns.histplot(x = "frequency", data = df_uk, bins = 30);

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
df_uk['TotalCost'] = df_uk['Quantity'] * df['UnitPrice']
df_uk.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0 536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1 536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2 536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3 536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4 536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  UnitPrice  CustomerID         Country  cancellation  \
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom         0.000
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom         0.000
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
#
#    Revenue        Date  recency  frequency  TotalCost
# ...

# %%
df_uk["monetary"] = df_uk.groupby("CustomerID")["TotalCost"].transform("sum")
df_uk.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0 536365.000    85123A   WHITE HANGING HEART T-LIGHT HOLDER     6.000
# 1 536365.000 71053.000                  WHITE METAL LANTERN     6.000
# 2 536365.000    84406B       CREAM CUPID HEARTS COAT HANGER     8.000
# 3 536365.000    84029G  KNITTED UNION FLAG HOT WATER BOTTLE     6.000
# 4 536365.000    84029E       RED WOOLLY HOTTIE WHITE HEART.     6.000
#
#           InvoiceDate  UnitPrice  CustomerID         Country  cancellation  \
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom         0.000
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom         0.000
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom         0.000
#
#    Revenue        Date  recency  frequency  TotalCost  monetary
# ...

# %% [markdown]
# 2. Plot RFM distributions

# %%
plt.figure(figsize=(16,9))
sns.histplot(x = "monetary", data = df_uk, bins = 30);

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
df_rfm = df_uk[["CustomerID", "recency", "frequency", "monetary"]]
df_rfm.head()
# Out:
#    CustomerID  recency  frequency  monetary
# 0   17850.000  373.000     34.000  5391.210
# 1   17850.000  373.000     34.000  5391.210
# 2   17850.000  373.000     34.000  5391.210
# 3   17850.000  373.000     34.000  5391.210
# 4   17850.000  373.000     34.000  5391.210

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
# Find quantile of each customer
def get_quantile(df, column, start_n_quantiles, end_n_quantiles, step=1):

    category_label = range(start_n_quantiles, end_n_quantiles, step)
    
    quantiles = pd.qcut(df[column], q=abs(
        end_n_quantiles - start_n_quantiles), labels=category_label)

    df = df.assign(name=quantiles.values)

    new_column_name = column + '_Q'

    return df.rename(columns={"name": new_column_name})

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %%
df_rfm_quantile = df_rfm.copy()

df_rfm_quantile = get_quantile(df_rfm_quantile, 'recency', 4, 0, -1)
df_rfm_quantile = get_quantile(df_rfm_quantile, 'frequency', 1, 5)
df_rfm_quantile = get_quantile(df_rfm_quantile, 'monetary', 1, 5)

df_rfm_quantile.head()
# Out:
#    CustomerID  recency  frequency  monetary recency_Q frequency_Q monetary_Q
# 0   17850.000  373.000     34.000  5391.210         1           4          3
# 1   17850.000  373.000     34.000  5391.210         1           4          3
# 2   17850.000  373.000     34.000  5391.210         1           4          3
# 3   17850.000  373.000     34.000  5391.210         1           4          3
# 4   17850.000  373.000     34.000  5391.210         1           4          3

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.
#
# > Indented block
#
# > Indented block

# %%
df_rfm_q2 = df_rfm_quantile.copy()

# %%
df_rfm_quantile.dropna(inplace=True)

# %%
# Concatenate RFM quartile values
def join_rfm(x): 
    return str(x['recency_Q']) + str(x['frequency_Q']) + str(x['monetary_Q'])

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %%
df_rfm_quantile['RFM_Level'] = df_rfm_quantile.apply(join_rfm, axis=1)

df_rfm_quantile.head()
# Out:
#    CustomerID  recency  frequency  monetary recency_Q frequency_Q monetary_Q  \
# 0   17850.000  373.000     34.000  5391.210         1           4          3
# 1   17850.000  373.000     34.000  5391.210         1           4          3
# 2   17850.000  373.000     34.000  5391.210         1           4          3
# 3   17850.000  373.000     34.000  5391.210         1           4          3
# 4   17850.000  373.000     34.000  5391.210         1           4          3
#
#    RFM_Level
# 0  1.04.03.0
# 1  1.04.03.0
# 2  1.04.03.0
# 3  1.04.03.0
# 4  1.04.03.0

# %%
df_rfm_quantile['RFM_Score'] = df_rfm_quantile[['recency_Q','frequency_Q','monetary_Q']].sum(axis=1)

df_rfm_quantile.sample(5)
# Out:
#         CustomerID  recency  frequency  monetary recency_Q frequency_Q  \
# 473524   15845.000   18.000      8.000  3711.770         2           3
# 403421   14096.000    5.000     17.000 65164.790         4           4
# 304824   15132.000   19.000      5.000   977.930         2           2
# 302465   13694.000    4.000     50.000 65039.620         4           4
# 429756   16033.000    6.000     20.000  8778.820         3           4
#
#        monetary_Q  RFM_Level  RFM_Score
# 473524          3  2.03.03.0          8
# 403421          4  4.04.04.0         12
# 304824          1  2.02.01.0          5
# 302465          4  4.04.04.0         12
# 429756          4  3.04.04.0         11

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %%
df_rfm_quantile.groupby('RFM_Score').agg({
    'recency': 'mean',
    'frequency': 'mean',
    'monetary': ['mean', 'count'] }).round(1)
# Out:
#           recency frequency  monetary
#              mean      mean      mean  count
# RFM_Score
# 3         160.300     1.700   475.400  39791
# 4          71.000     2.600   839.000  33319
# 5          53.300     3.700  1441.000  34468
# 6          37.500     5.000  1804.300  37161
# 7          25.200     6.500  2341.000  32930
# 8          22.600     9.000  3321.800  35470
# 9          12.000    10.200  4137.200  35914
# 10         10.300    15.800  8743.300  25331
# 11          7.200    23.100 13767.800  26444
# 12          2.600    69.600 33563.000  48399

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3)
fig.suptitle('Histograms')
df_rfm.recency.plot.hist(ax = ax1, figsize = (12,12), color='pink');
df_rfm.frequency.sort_values().plot.hist(ax = ax2, color='pink');
df_rfm.monetary.sort_values().plot.hist(ax = ax3, color='pink');
ax1.set_ylabel('recency_Q')
ax2.set_ylabel('frequency_Q')
ax3.set_ylabel('monetary_Q')
# Out:
# Text(0, 0.5, 'monetary_Q')

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales). We can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %% [markdown]
# # 4. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

plt.rcParams["figure.figsize"] = (10,7)
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")
pd.set_option('display.max_rows', 500)

# %%
df_rfm.head() #buraya rfm dataframei gelecek.

#df_rfm.head()  olabilir
# Out:
#    CustomerID  recency  frequency  monetary
# 0   17850.000  373.000     34.000  5391.210
# 1   17850.000  373.000     34.000  5391.210
# 2   17850.000  373.000     34.000  5391.210
# 3   17850.000  373.000     34.000  5391.210
# 4   17850.000  373.000     34.000  5391.210

# %%
df_rfm.shape

#df_rfm.head()
# Out:
# (480549, 4)

# %%
df_rfm.info()

#df_rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480549 entries, 0 to 525444
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   CustomerID  349227 non-null  float64
#  1   recency     349227 non-null  float64
#  2   frequency   349227 non-null  float64
#  3   monetary    349227 non-null  float64
# dtypes: float64(4)
# memory usage: 34.5 MB

# %%
df_rfm.describe()
# Out:
#        CustomerID    recency  frequency   monetary
# count  349227.000 349227.000 349227.000 349227.000
# mean    15548.334     41.855     16.461   7780.215
# std      1594.403     65.606     31.379  17515.156
# min     12346.000      1.000      1.000      0.000
# 25%     14191.000      5.000      3.000   1048.280
# 50%     15518.000     17.000      7.000   2515.840
# 75%     16931.000     45.000     15.000   5625.080
# max     18287.000    374.000    210.000 259657.300

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
df_rfm.corr()
# Out:
#             CustomerID  recency  frequency  monetary
# CustomerID       1.000    0.034     -0.079    -0.030
# recency          0.034    1.000     -0.235    -0.206
# frequency       -0.079   -0.235      1.000     0.514
# monetary        -0.030   -0.206      0.514     1.000

# %%
sns.heatmap(data = df_rfm.corr(), annot = True, cmap="crest")

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
#plt.figure(figsize=(20,10))
#sns.pairplot(df_rfm[['Recency', 'Frequency', 'Monetary','Segments']]);

# %%
df_rfm_quantile.sample(5)
# Out:
#         CustomerID  recency  frequency  monetary recency_Q frequency_Q  \
# 351183   13314.000    2.000      3.000   775.940         4           1
# 77654    16771.000   34.000      5.000  2242.610         2           2
# 432740   17014.000    9.000      3.000   583.430         3           1
# 201844   16023.000   47.000      3.000   719.810         1           1
# 89562    13089.000    3.000     97.000 58762.080         4           4
#
#        monetary_Q  RFM_Level  RFM_Score
# 351183          1  4.01.01.0          6
# 77654           2  2.02.02.0          6
# 432740          1  3.01.01.0          5
# 201844          1  1.01.01.0          3
# 89562           4  4.04.04.0         12

# %%
#plt.figure(figsize=(20,10))
#sns.pairplot(df_rfm_quantile[['recency_Q', 'frequency_Q', 'monetary_Q','RFM_Score']],hue=None);

# %%
# plot the distribution of RFM values

sns.distplot(df_rfm['recency'])
plt.show()

# %%
sns.distplot(df_rfm['frequency'])
plt.show()

# %%
sns.distplot(df_rfm['monetary'])
plt.show()

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. Logarithmic Tranformation can be [link text](https://)
# used to normalize the values in a column.
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %%
from sklearn.preprocessing import StandardScaler

# %%
df_rfm_log = df_rfm.copy()
df_rfm_log.describe()
# Out:
#        CustomerID    recency  frequency   monetary
# count  349227.000 349227.000 349227.000 349227.000
# mean    15548.334     41.855     16.461   7780.215
# std      1594.403     65.606     31.379  17515.156
# min     12346.000      1.000      1.000      0.000
# 25%     14191.000      5.000      3.000   1048.280
# 50%     15518.000     17.000      7.000   2515.840
# 75%     16931.000     45.000     15.000   5625.080
# max     18287.000    374.000    210.000 259657.300

# %%
df_rfm_log = df_rfm_log.drop(columns='CustomerID', axis=1)

# %%
df_rfm_log.head()
# Out:
#    recency  frequency  monetary
# 0  373.000     34.000  5391.210
# 1  373.000     34.000  5391.210
# 2  373.000     34.000  5391.210
# 3  373.000     34.000  5391.210
# 4  373.000     34.000  5391.210

# %%
df_rfm_log.describe()
# Out:
#          recency  frequency   monetary
# count 349227.000 349227.000 349227.000
# mean      41.855     16.461   7780.215
# std       65.606     31.379  17515.156
# min        1.000      1.000      0.000
# 25%        5.000      3.000   1048.280
# 50%       17.000      7.000   2515.840
# 75%       45.000     15.000   5625.080
# max      374.000    210.000 259657.300

# %%
df_rfm_log = df_rfm_log.dropna()

# %%
df_rfm_log
# Out:
#         recency  frequency  monetary
# 0       373.000     34.000  5391.210
# 1       373.000     34.000  5391.210
# 2       373.000     34.000  5391.210
# 3       373.000     34.000  5391.210
# 4       373.000     34.000  5391.210
# ...         ...        ...       ...
# 525440    1.000     13.000  4206.390
# 525441    1.000     24.000 12245.960
# 525442    1.000     24.000 12245.960
# 525443    1.000     24.000 12245.960
# 525444    1.000     24.000 12245.960
#
# [349227 rows x 3 columns]

# %%
#df_rfm_log1 = np.log(df_rfm_log)
scaler = StandardScaler()
scaler.fit(df_rfm_log)
df_rfm_normalized = scaler.transform(df_rfm_log)

# %%
#Normalized data

sns.pairplot(data = pd.DataFrame(df_rfm_normalized));

# %%
pd.DataFrame(df_rfm_normalized).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349227 entries, 0 to 349226
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       349227 non-null  float64
#  1   1       349227 non-null  float64
#  2   2       349227 non-null  float64
# dtypes: float64(3)
# memory usage: 8.0 MB

# %%
#Normalized_Recency
sns.distplot(pd.DataFrame(df_rfm_normalized)[0])
plt.show()

# %%
#Normalized_Frequency
sns.distplot(pd.DataFrame(df_rfm_normalized)[1])
plt.show()

# %%
#Normalized_Monetary
sns.distplot(pd.DataFrame(df_rfm_normalized)[2])
plt.show()

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.preprocessing import scale
from sklearn.metrics.cluster import adjusted_rand_score
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_samples,silhouette_score
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
ssd1 = []

K = range(1,10)

for k in K:
    model1 = KMeans(n_clusters =k, random_state=42)
    model1.fit(df_rfm_normalized)
    ssd1.append(model1.inertia_)

# %%
plt.plot(K, ssd1, "bo--")
plt.xlabel("Different k Values")
plt.ylabel("Inertia-Error") 
plt.title("Elbow Method")
# Out:
# Text(0.5, 1.0, 'Elbow Method')

# %%
ssd1
# Out:
# [1047680.9999999772,
#  615121.8910788976,
#  359738.7364230151,
#  254865.52474059362,
#  185629.59839322287,
#  141839.4260346351,
#  108600.26067342996,
#  86433.58578198955,
#  66578.71599887463]

# %%
from yellowbrick.cluster import KElbowVisualizer

model_1 = KMeans(random_state=42)
visualizer = KElbowVisualizer(model_1, k=(2,9))

visualizer.fit(df_rfm_normalized)       
visualizer.poof();

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
range_n_clusters = range(2,10)
for num_clusters in range_n_clusters:
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(df_rfm_normalized)
    cluster_labels = kmeans.labels_
    # silhouette score
    silhouette_avg = silhouette_score(df_rfm_normalized, cluster_labels)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")

# %%
from yellowbrick.cluster import SilhouetteVisualizer

model_2 = KMeans(n_clusters=, random_state=42)        
visualizer = SilhouetteVisualizer(model_2)

visualizer.fit(df_rfm_normalized)   
visualizer.poof();

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %%
kmeans = KMeans(n_clusters = ).fit(df_rfm_normalized)
labels = kmeans.labels_
df_rfm_normalized['labels']=labels

df_rfm_normalized.head()

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %% [markdown]
# ### iv. Assign the Label

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the RFM Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# **Conclusion**
#
# * Write down your conclusions about clustering

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %%
import pandas as pd
df = pd.read_excel('Online Retail.xlsx')

# %%
import datetime as dt
import matplotlib.pyplot as plt

#This function helps us to return the date's day value as 1st of the month
def get_month(x): return dt.datetime(x.year, x.month, 1)

#Df grouped by CustomerID and InvoiceMonth and chosed the min value of InvoiceMonth
df['InvoiceMonth'] = df['InvoiceDate'].apply(get_month)
grouping = df.groupby('CustomerID')['InvoiceMonth']
df['CohortMonth'] = grouping.transform('min')

# %%
# Calculated Time Offset
def get_date_int(df, column):
    year = df[column].dt.year
    month = df[column].dt.month
    day = df[column].dt.day
    return year, month, day

# %%
invoice_year, invoice_month, _ = get_date_int(df, 'InvoiceMonth')
cohort_year, cohort_month, _ = get_date_int(df, 'CohortMonth')

years_diff = invoice_year - cohort_year
months_diff = invoice_month - cohort_month

# %%
df['CohortIndex'] = years_diff * 12 + months_diff + 1

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 separate series for each of the two columns

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %%
grouping = df.groupby(['CohortMonth', 'CohortIndex'])
cohort_data = grouping['CustomerID'].apply(pd.Series.nunique)
cohort_data = cohort_data.reset_index()
cohort_counts = cohort_data.pivot(index='CohortMonth', 
                                  columns='CohortIndex', 
                                  values='CustomerID')
cohort_counts

# %%
import seaborn as sns
sns.set(style='white')
plt.figure(figsize=(12, 8))
plt.title('Cohort Analysis - Customers Retention')
sns.heatmap(cohort_counts, cmap='Blues', annot=True, fmt='.0f', linewidths=.5, annot_kws={"size": 14})
plt.xlabel('Cohort Index')
plt.ylabel('Cohort Month')
plt.show()

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_sizes = cohort_counts.iloc[:,0]
retention = cohort_counts.divide(cohort_sizes, axis=0)
retention.round(3) * 100

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %%
import seaborn as sns
plt.figure(figsize=(15, 8))
plt.title('Retention rates')
sns.heatmap(data = retention,
annot = True,
fmt = '.0%',
vmin = 0.0,
vmax = 0.5,
cmap = 'Blues')
plt.show()

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
grouping = df.groupby(['CohortMonth', 'CohortIndex'])
cohort_data = grouping['Quantity'].mean()
cohort_data = cohort_data.reset_index()
average_quantity = cohort_data.pivot(index='CohortMonth',
                                     columns='CohortIndex',
                                     values='Quantity')                                     
average_quantity.round(1)

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(15, 8))
plt.title('Average Quantity Sold')
sns.heatmap(data = average_quantity,
annot = True,
cmap = 'Blues')
plt.show()

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
df['Sum'] = df['Quantity'] * df['UnitPrice']
grouping = df.groupby(['CohortMonth', 'CohortIndex'])
cohort_data = grouping['Sum'].mean()
cohort_data = cohort_data.reset_index()
average_sales = cohort_data.pivot(index='CohortMonth',
                                     columns='CohortIndex',
                                     values='Sum')                                     
average_sales.round(1)

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(15, 8))
plt.title('Average Quantity Sold')
sns.heatmap(data = average_sales,
annot = True,
cmap = 'Blues')
plt.show()

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
